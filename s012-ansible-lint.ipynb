# %% [markdown]
# # Introduction

# %% [markdown]
# * Let's say you have been using Ansible to automate your infrastructure, and over time, you have written a multitude of playbooks.
# * As your infrastructure expands, so does the complexity of your playbooks.
# * Some playbooks start to become more difficult to understand and maintain than others.
# * You realize that you need a mechanism to ensure consistency and quality across all your playbooks.
# * This is where **`ansible-lint`** enters the scene.

# %% [markdown]
# # Why do we need `ansible-lint`?

# %% [markdown]
# ![image.png](attachment:2269ea18-437f-4b17-8270-ef8cb6d6cb54.png)
#
# * The `ansible-lint` is a command-line tool that performs linting on Ansible playbooks, roles, and collections.
# * It checks your code for potential errors, bugs, stylistic errors, and suspicious constructs.
# * It's akin to having a seasoned Ansible mentor guiding you, providing valuable insights, and catching issues that might have slipped past your notice.

# %% [markdown]
# # How to use `ansible-lint`?

# %% [markdown]
# ![image.png](attachment:09b44d7a-73f6-4fb2-90f4-581dc59f8f38.png)
#
# Let's have a look at an example to understand the full power of Ansible Lint.
#
# Here's our stylish Ansible playbook named `style_example.yaml`.
# * It has some tasks to install and configure NGINX, but there are some style-related issues.
# * First, we have an **inconsistent indentation** in the playbook.
# * Some tasks have two spaces of indentation, while one task has four spaces.
# * Second, we notice that the **task names are inconsistent**, too.
# * One task follows a sentence-like style, while the other goes with the concise approach.
#
# Let's run Ansible Lint on this playbook to see what it finds.
#
# The output will be something like this.
#
# ![image.png](attachment:29e7333a-4e92-4104-982e-18839276a70d.png)
#
# There you have it, Ansible Lint catches all these style-related issues and provides us with warnings.
# * It tells us about the **incorrect indentation**, the **deprecated `apt` and `service` modules**, and **even the missing name attribute for one task**.
# * You can use this feedback to refine your playbook.
#
# **If the command completes without any output, that means no issues were found.**
