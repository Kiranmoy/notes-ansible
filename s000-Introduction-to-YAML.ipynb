# %% [markdown]
# # What is YAML?

# %% [markdown]
# ![image.png](attachment:7e5773f8-9b7a-4e55-9bd4-56fa5948dcc9.png)

# %% [markdown]
# ![image.png](attachment:42380f46-878a-4fbf-bbae-cefb22b4c7fc.png)
#
# ![image.png](attachment:99b29c4b-103a-4d36-9ec9-4fd8fad8d71f.png)

# %% [markdown]
# ![image.png](attachment:d1f24515-4471-4eb8-bd90-35e6af1cd987.png)

# %% [markdown]
# ![image.png](attachment:d4f2bc2f-38f8-4ec8-8326-28df0e52bb0b.png)
#
# ![image.png](attachment:025e58ee-a631-4543-8884-76dacc61b900.png)
#
# ![image.png](attachment:653bec29-1226-46dd-8219-29b30b1c2c23.png)

# %% [markdown]
# ![image.png](attachment:a524a87f-858f-4d86-b46d-8e9c84bc3c7c.png)

# %% [markdown]
# ![image.png](attachment:d889b780-5bc2-406c-8087-8503e5d9edd0.png)
